# %%
import os

checkpoint_file = 'model/checkpoint.pth'
memory_file = 'model/memory.pkl'

if os.path.exists(checkpoint_file):
    print(f"Checkpoint file '{checkpoint_file}' exists.")
else:
    print(f"Checkpoint file '{checkpoint_file}' is missing!")

if os.path.exists(memory_file):
    print(f"Memory file '{memory_file}' exists.")
else:
    print(f"Memory file '{memory_file}' is missing!")
# Out:
# Checkpoint file 'model/checkpoint.pth' is missing!
# Memory file 'model/memory.pkl' is missing!

# %%
import pandas as pd

games_df = pd.read_csv('game_results.csv')
games_df
# Out:
#      game  epsilon  exploration  exploitation  score  record  \
# 0       1  1.00000          184             0      0       0
# 1       2  0.99901          361             0      0       0
# 2       3  0.99802           98             0      0       0
# 3       4  0.99703          121             0      0       0
# 4       5  0.99604          296             1      0       0
# ..    ...      ...          ...           ...    ...     ...
# 195   196  0.10000           23           240      0       1
# 196   197  0.10000            4            31      0       1
# 197   198  0.10000           40           321      0       1
# 198   199  0.10000           27           334      0       1
# 199   200  0.10000           33           328      0       1
#
#                       timestamp
# 0    2025-02-12 12:51:13.241992
# 1    2025-02-12 12:51:16.759383
# 2    2025-02-12 12:51:17.848244
# 3    2025-02-12 12:51:19.157139
# 4    2025-02-12 12:51:22.020327
# ..                          ...
# ...

# %%
import pandas as pd

checkpoint_df = pd.read_csv('checkpoint_results.csv')
checkpoint_df
# Out:
#    games_range  epsilon  gamma     LR  total_exploration  total_exploitation
# 0         1-10  0.99010   0.99  0.002               2220                   9
# 1        11-20  0.97921   0.99  0.002               2599                  34
# 2        21-30  0.96931   0.99  0.002               2550                  73
# 3        31-40  0.95941   0.99  0.002               2243                  83
# 4        41-50  0.94951   0.99  0.002               1718                  72
# 5        51-60  0.93961   0.99  0.002               2412                 153
# 6        61-70  0.92971   0.99  0.002               2845                 188
# 7        71-80  0.09901   0.99  0.002                279                1221
# 8        81-90  0.09901   0.99  0.002                210                1512
# 9       91-100  0.09901   0.99  0.002                236                2202
# 10     101-110  0.09901   0.99  0.002                248                2307
# ...
